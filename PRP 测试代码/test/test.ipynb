# %%
import pandas as pd

df = pd.read_csv('F:/大学/git_book/traffic-big-data-theory-and-applications/样例数据/DATASET-B.csv')
df.sort_values(by=['rowid', 'colid', 'time_id']).reset_index(drop=True)
# Out:
#       rowid  colid  time_id  aveSpeed       gridAcc  volume     speed_std  \
# 0       0.0    0.0      0.0  0.000001  1.006333e-08   66.95  1.009898e-06
# 1       0.0    0.0      0.0  0.000001  1.257757e-08   54.15  1.032747e-06
# 2       0.0    0.0      0.0  0.000001  1.059624e-08   57.15  9.502379e-07
# 3       0.0    0.0      0.0  0.000001  1.212358e-08   72.00  1.034375e-06
# 4       0.0    0.0      0.0  0.000001  1.723324e-08   92.00  1.024261e-06
# ...     ...    ...      ...       ...           ...     ...           ...
# 4315    0.0    0.0    143.0  0.000001  5.663320e-09  592.00  1.041172e-06
# 4316    0.0    0.0    143.0  0.000001  5.990544e-09  533.00  1.049843e-06
# 4317    0.0    0.0    143.0  0.000001  5.114397e-09  434.00  1.063719e-06
# 4318    0.0    0.0    143.0  0.000002  4.390111e-09  555.00  1.053122e-06
# 4319    0.0    0.0    143.0  0.000001  5.487947e-09  541.00  1.047412e-06
#
#         stopNum      minSpeed  freeSpeed  speedRatio      date  labels
# ...
