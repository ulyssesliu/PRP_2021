# %%
import sys
sys.path.append(r'D:/jupyter/PRP 测试代码')
from OsmDownloader import OsmDownloader

downloader = OsmDownloader(area='成都市')
downloader.download_shapefile(path='F:/大学/第40期PRP/路网数据/OSM')
# Out:
# ...
# 开始下载数据！
# ...
# [成都市]抽取线数据: 100%|██████████| 633803/633803 [00:09<00:00, 67104.78it/s]
# ...
# 数据下载完成！
# ...
# 开始导出数据！
# ...
# 数据导出成功！
